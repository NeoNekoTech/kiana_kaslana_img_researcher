# %%
from test_pre_train_model.ssd_anime_face_detect import ssd_anime_face_detect
import cv2 as cv 
import matplotlib.pyplot as plt

# %%
plt.imshow(ssd_anime_face_detect("image copy 2.png", 'test_pre_train_model/ssd_anime_face_detect.pth'))
# Out:
# 723.6543 880.84686 161.23509674072267 303.30484
