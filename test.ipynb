# %%
from test_pre_train_model.ssd_anime_face_detect import ssd_anime_face_detect
import cv2 as cv 
import matplotlib.pyplot as plt

# %%
plt.imshow(ssd_anime_face_detect("imgs_test\kiana/4efeda2db7d88c0538816b4c06fd7e92.webp", 'test_pre_train_model/ssd_anime_face_detect.pth'))
# Out:
# 1026.655 1288.4015 138.85446 366.04785
# <>:1: SyntaxWarning: invalid escape sequence '\k'
# <>:1: SyntaxWarning: invalid escape sequence '\k'
# C:\Users\ssea2\AppData\Local\Temp\ipykernel_7516\1991812375.py:1: SyntaxWarning: invalid escape sequence '\k'
#   plt.imshow(ssd_anime_face_detect("imgs_test\kiana/4efeda2db7d88c0538816b4c06fd7e92.webp", 'test_pre_train_model/ssd_anime_face_detect.pth'))
